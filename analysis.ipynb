# %% [markdown]
# ## Importing linraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('dummy_age_height_dataset.csv')
df.head(10)
# Out:
#    Age  Height_cm
# 0   54      182.4
# 1   44      155.7
# 2   30      173.4
# 3   58      189.7
# 4   23      189.7
# 5   36      150.6
# 6   54      162.4
# 7   34      171.7
# 8   38      156.8
# 9   26      163.3

# %% [markdown]
# ## EDA

# %%
print("data shape:", df.shape)
print("data info:", df.info())
# Out:
# data shape: (200, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        200 non-null    int64
#  1   Height_cm  200 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 KB
# data info: None

# %%
df.isnull().sum()
# Out:
# Age          0
# Height_cm    0
# dtype: int64

# %%
x = df['Age'].values.reshape(-1, 1)
y = df['Height_cm'].values

# %%
import matplotlib.pyplot as plt

# Use common column names (case-insensitive)
cols_lower = {c.lower(): c for c in df.columns}
age_col = cols_lower.get("age", "Age") if "age" in cols_lower else df.columns[0]
height_col = cols_lower.get("height", "Height") if "height" in cols_lower else df.columns[1]

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)

axes[0].hist(df[age_col].dropna(), bins=20, edgecolor="white")
axes[0].set_title(f"Distribution of {age_col}")
axes[0].set_xlabel(age_col)
axes[0].set_ylabel("Count")

axes[1].hist(df[height_col].dropna(), bins=20, edgecolor="white")
axes[1].set_title(f"Distribution of {height_col}")
axes[1].set_xlabel(height_col)
axes[1].set_ylabel("Count")

plt.show()

# %% [markdown]
# ## Plotting
